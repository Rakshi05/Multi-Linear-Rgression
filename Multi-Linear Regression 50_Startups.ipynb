# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv("50_Startups.csv")

# %%
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
state = pd.get_dummies(data['State'],drop_first=False)

# %%
state
# Out:
#     California  Florida  New York
# 0            0        0         1
# 1            1        0         0
# 2            0        1         0
# 3            0        0         1
# 4            0        1         0
# 5            0        0         1
# 6            1        0         0
# 7            0        1         0
# 8            0        0         1
# 9            1        0         0
# 10           0        1         0
# 11           1        0         0
# 12           0        1         0
# 13           1        0         0
# 14           0        1         0
# 15           0        0         1
# 16           1        0         0
# 17           0        0         1
# 18           0        1         0
# 19           0        0         1
# 20           1        0         0
# 21           0        0         1
# 22           0        1         0
# 23           0        1         0
# 24           0        0         1
# 25           1        0         0
# ...

# %%
data1 = data.drop("State",axis=1)

# %%
data1.shape
# Out:
# (50, 4)

# %%
data1 = data1.rename(columns={"R&D Spend":"RD","Administration":"Adm","Marketing Spend":"Mrkt","Profit":"Profit"})

# %%
data1
# Out:
#            RD        Adm       Mrkt     Profit
# 0   165349.20  136897.80  471784.10  192261.83
# 1   162597.70  151377.59  443898.53  191792.06
# 2   153441.51  101145.55  407934.54  191050.39
# 3   144372.41  118671.85  383199.62  182901.99
# 4   142107.34   91391.77  366168.42  166187.94
# 5   131876.90   99814.71  362861.36  156991.12
# 6   134615.46  147198.87  127716.82  156122.51
# 7   130298.13  145530.06  323876.68  155752.60
# 8   120542.52  148718.95  311613.29  152211.77
# 9   123334.88  108679.17  304981.62  149759.96
# 10  101913.08  110594.11  229160.95  146121.95
# 11  100671.96   91790.61  249744.55  144259.40
# 12   93863.75  127320.38  249839.44  141585.52
# 13   91992.39  135495.07  252664.93  134307.35
# 14  119943.24  156547.42  256512.92  132602.65
# 15  114523.61  122616.84  261776.23  129917.04
# 16   78013.11  121597.55  264346.06  126992.93
# 17   94657.16  145077.58  282574.31  125370.37
# 18   91749.16  114175.79  294919.57  124266.90
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RD      50 non-null     float64
#  1   Adm     50 non-null     float64
#  2   Mrkt    50 non-null     float64
#  3   Profit  50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
data1.isnull().sum()
# Out:
# RD        0
# Adm       0
# Mrkt      0
# Profit    0
# dtype: int64

# %%
data1.corr()
# Out:
#               RD       Adm      Mrkt    Profit
# RD      1.000000  0.241955  0.724248  0.972900
# Adm     0.241955  1.000000 -0.032154  0.200717
# Mrkt    0.724248 -0.032154  1.000000  0.747766
# Profit  0.972900  0.200717  0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data1)

# %%
# Preparing model

import statsmodels.formula.api as smf
model = smf.ols('Profit~RD+Adm+Mrkt',data=data1).fit()

# %%
# Coefficients
model.params
# Out:
# Intercept    50122.192990
# RD               0.805715
# Adm             -0.026816
# Mrkt             0.027228
# dtype: float64

# %%
# t & p- values
print(model.tvalues, '\n' ,model.pvalues)
# Out:
# Intercept     7.626218
# RD           17.846374
# Adm          -0.525507
# Mrkt          1.655077
# dtype: float64
#  Intercept    1.057379e-09
# RD           2.634968e-22
# Adm          6.017551e-01
# Mrkt         1.047168e-01
# dtype: float64

# %%
# R squarred values
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %% [markdown]
# # Simple linear regression model

# %%
mdl_rd = smf.ols('Profit~RD',data=data1).fit()
print(mdl_rd.tvalues, '\n' ,mdl_rd.pvalues)
# Out:
# Intercept    19.320288
# RD           29.151139
# dtype: float64
#  Intercept    2.782697e-24
# RD           3.500322e-32
# dtype: float64

# %%
mdl_m = smf.ols('Profit~Mrkt',data=data1).fit()
print(mdl_m.tvalues, '\n' ,mdl_m.pvalues)
# Out:
# Intercept    7.808356
# Mrkt         7.802657
# dtype: float64
#  Intercept    4.294735e-10
# Mrkt         4.381073e-10
# dtype: float64

# %%
mdl_rm = smf.ols('Profit~RD+Mrkt',data=data1).fit()
print(mdl_rm.tvalues, '\n' ,mdl_rm.pvalues)
# Out:
# Intercept    17.463582
# RD           19.265555
# Mrkt          1.927052
# dtype: float64
#  Intercept    3.504062e-22
# RD           6.040433e-24
# Mrkt         6.003040e-02
# dtype: float64

# %%
rsq_rd = smf.ols('RD~Mrkt+Adm',data=data1).fit().rsquared
vif_rd = 1/(1-rsq_rd)

rsq_ad = smf.ols('Adm~Mrkt+RD',data=data1).fit().rsquared
vif_ad = 1/(1-rsq_ad)

rsq_m = smf.ols('Mrkt~RD+Adm',data=data1).fit().rsquared
vif_m = 1/(1-rsq_m)

# %%
d = {'Variable':['Rd','Adm','Mrkt'],'VIF':[vif_rd,vif_ad,vif_m]}
Vif = pd.DataFrame(d)
Vif
# Out:
#   Variable       VIF
# 0       Rd  2.468903
# 1      Adm  1.175091
# 2     Mrkt  2.326773

# %% [markdown]
# # Residual Analysis

# %%
import statsmodels.api as sm
qqplot = sm.qqplot(model.resid,line='q')
plt.title("Q-Q plot",fontsize=20,fontweight='bold')
plt.show()
# Out:
# C:\Users\lavanya\anaconda\anaconda1\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
list(np.where(model.resid>10000))
# Out:
# [array([10, 12, 16, 36, 38, 45], dtype=int64)]

# %%
list(np.where(model.resid<-30000))
# Out:
# [array([49], dtype=int64)]

# %% [markdown]
# # Residual plot

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),get_standardized_values(model.resid))
plt.title("Residual Plot")
plt.xlabel("Standardized fitted values")
plt.ylabel("Standardized residual values")
plt.show()

# %%
# Residual vs Regressor

fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "RD", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Adm", fig=fig)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Mrkt", fig=fig)
plt.show()

# %% [markdown]
# # Cook's Distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data1)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (49, 0.28808229275432634)

# %% [markdown]
# # High influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k=data1.shape[1]
n=data1.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff
# Out:
# 0.3

# %%
data1[data1.index.isin([49])]
# Out:
#      RD       Adm      Mrkt   Profit
# 49  0.0  116983.8  45173.06  14681.4

# %% [markdown]
# # Improvig model

# %%
data_new = pd.read_csv("50_Startups.csv")

# %%
data2 = data_new.drop(data_new.index[[49]],axis=0).reset_index()

# %%
data2
# Out:
#     index  R&D Spend  Administration  Marketing Spend       State     Profit
# 0       0  165349.20       136897.80        471784.10    New York  192261.83
# 1       1  162597.70       151377.59        443898.53  California  191792.06
# 2       2  153441.51       101145.55        407934.54     Florida  191050.39
# 3       3  144372.41       118671.85        383199.62    New York  182901.99
# 4       4  142107.34        91391.77        366168.42     Florida  166187.94
# 5       5  131876.90        99814.71        362861.36    New York  156991.12
# 6       6  134615.46       147198.87        127716.82  California  156122.51
# 7       7  130298.13       145530.06        323876.68     Florida  155752.60
# 8       8  120542.52       148718.95        311613.29    New York  152211.77
# 9       9  123334.88       108679.17        304981.62  California  149759.96
# 10     10  101913.08       110594.11        229160.95     Florida  146121.95
# ...

# %%
data2 = data2.drop("index",axis=1)

# %%
data2.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data2 = data2.rename(columns={"R&D Spend":"RD","Administration":"Adm","Marketing Spend":"Mrkt","Profit":"Profit"})

# %%
final_mdl = smf.ols('Profit~Adm+RD',data=data2).fit()

# %%
(final_mdl.rsquared,final_mdl.aic)
# Out:
# (0.9584519070123048, 1022.0654576388338)

# %%
final_mdl = smf.ols('Profit~Mrkt+RD',data=data2).fit()

# %%
(final_mdl.rsquared,final_mdl.aic)
# Out:
# (0.9610856807456628, 1018.8564801588338)

# %%
model_influence_v = final_mdl.get_influence()
(c_v, _) = model_influence_v.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(data2)),np.round(c_v,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c_v),np.max(c_v))
# Out:
# (46, 0.1833755649133837)

# %%
data3=data2.drop(data2.index[[46]],axis=0)

# %%
data3 = data3.reset_index()

# %%
data3 = data3.drop("index",axis=1)

# %%
data3
# Out:
#            RD        Adm       Mrkt       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
final_mdl_v = smf.ols('Profit~RD+Adm',data=data3).fit()

# %%
(final_mdl_v.rsquared,final_mdl_v.aic)
# Out:
# (0.9559194683601144, 1002.1513539285583)

# %%
final_mdl_v = smf.ols('Profit~RD+Mrkt',data=data3).fit()

# %%
(final_mdl_v.rsquared,final_mdl_v.aic)
# Out:
# (0.9603203117008039, 997.1027715983952)

# %%
model_influence_v = final_mdl_v.get_influence()
(c_v, _) = model_influence_v.cooks_distance

# %%
fig= plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(data3)),np.round(c_v,3));
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c_v),np.max(c_v))
# Out:
# (47, 0.14544403432423783)

# %%
data4 = data3.drop(data3.index[[47]],axis=0)

# %%
data4 = data4.reset_index()

# %%
data4 = data4.drop("index",axis=1)

# %%
data4
# Out:
#            RD        Adm       Mrkt       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
final_mdl_v = smf.ols('Profit~RD+Adm',data=data4).fit()

# %%
(final_mdl_v.rsquared,final_mdl_v.aic)
# Out:
# (0.9588328809184866, 974.2908843857945)

# %%
final_mdl_v = smf.ols('Profit~RD+Mrkt',data=data4).fit()

# %%
(final_mdl_v.rsquared,final_mdl_v.aic)
# Out:
# (0.9601156240945742, 972.8030903954614)

# %% [markdown]
# # Model Prediction

# %%
new = pd.DataFrame({'RD':50000,'Adm':65000,'Mrkt':80000},index=[0])
new
# Out:
#       RD    Adm   Mrkt
# 0  50000  65000  80000

# %%
final_mdl_v.predict(new)
# Out:
# 0    91489.870646
# dtype: float64

# %%
pred_y = final_mdl_v.predict(data4)

# %%
pred_y
# Out:
# 0     189947.201324
# 1     186999.822978
# 2     179027.346980
# 3     171482.332145
# 4     169247.365053
# 5     161530.559248
# 6     155972.916982
# 7     159097.044290
# 8     151444.171338
# 9     153307.099523
# 10    134923.454028
# 11    134665.050008
# 12    129603.773886
# 13    128303.006136
# 14    149218.750236
# 15    145357.310922
# 16    118281.687354
# 17    131251.235074
# 18    129486.825745
# 19    115997.097979
# 20    118081.477664
# 21    119704.718204
# 22    116551.220743
# 23    111791.203829
# 24    113563.227948
# 25    104270.418663
# 26    112076.670225
# 27    116758.125060
# 28    104662.038461
# 29    103974.650876
# 30    100771.578379
# 31    100039.188967
# 32    100368.772429
# 33     99925.048808
# 34     93055.901839
# 35     92578.859801
# 36     79530.916054
# 37     90858.593846
# 38     72744.787178
# 39     86047.332692
# 40     78683.242548
# 41     77773.594805
# 42     74078.780204
# 43     64394.869285
# 44     69125.367568
# ...

# %%
d2={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_mdl_v.rsquared]}
table=pd.DataFrame(d2)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.960116
